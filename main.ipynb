# %%
import pandas as pd

# %%
df = pd.read_csv('carpetas-de-investigacion-pgj-cdmx.csv ')

# %% [markdown]
# dataset obenido el 03/12/2020 antes de las 20:44hrs [aquí](https://datos.cdmx.gob.mx/explore/dataset/carpetas-de-investigacion-pgj-cdmx/export/?dataChart=...%3D%3D)

# %%
df
# Out:
#         año_hechos  mes_hechos         fecha_hechos  \
# 0           2016.0       Enero  2016-01-05 17:00:00
# 1           2017.0   Noviembre  2017-11-01 14:00:00
# 2           2017.0   Noviembre  2017-11-01 16:40:00
# 3           2015.0   Diciembre  2015-12-30 20:00:00
# 4           2018.0        Mayo  2018-05-16 16:00:00
# ...            ...         ...                  ...
# 808866      2017.0       Enero  2017-01-24 15:00:00
# 808867      2017.0       Enero  2017-01-24 20:18:00
# 808868      2017.0       Enero  2017-01-30 20:35:00
# 808869      2016.0  Septiembre  2016-09-13 12:00:00
# 808870      2017.0       Enero  2017-01-31 03:20:00
#
#                                                    delito  \
# 0                                       LESIONES CULPOSAS
# 1       ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
# 2          ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
# 3                                                  FRAUDE
# ...

# %%
dfdrops = df.drop(columns=['año_hechos','mes_hechos','categoria_delito','Geopoint','longitud','latitud','calle_hechos2','calle_hechos','colonia_hechos','mes_inicio','ao_inicio'])

# %%
dfdrops
# Out:
#                fecha_hechos  \
# 0       2016-01-05 17:00:00
# 1       2017-11-01 14:00:00
# 2       2017-11-01 16:40:00
# 3       2015-12-30 20:00:00
# 4       2018-05-16 16:00:00
# ...                     ...
# 808866  2017-01-24 15:00:00
# 808867  2017-01-24 20:18:00
# 808868  2017-01-30 20:35:00
# 808869  2016-09-13 12:00:00
# 808870  2017-01-31 03:20:00
#
#                                                    delito  \
# 0                                       LESIONES CULPOSAS
# 1       ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
# 2          ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
# 3                                                  FRAUDE
# 4                         ROBO A REPARTIDOR CON VIOLENCIA
# ...                                                   ...
# 808866         ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA
# 808867     ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
# 808868                                  LESIONES CULPOSAS
# ...

# %%
tiempo, delito, fiscalía, agencia, unidad_investigación, delta_tiempo_ocurrencia_reporte, alcaldía_hechos
